# %%
import pandas as pd

# %%
df = pd.read_csv('../data.csv')

# %%
df.head()
# Out:
#           SeriesName  tvdbID Network  tvdbRating  indicator  Action  \
# 0  Doctor Who (2005)   78804     BBC           9       1341       0
# 1    Game of Thrones  121361     HBO          10        920       0
# 2    Sons of Anarchy   82696      FX           9        828       0
# 3              Bones   75682     FOX           9        792       0
# 4             Fringe   82066     FOX           9        783       0
#
#    Adventure  Animation  Children    Comedy   ...     Romance  \
# 0   0.333333          0         0  0.000000   ...           0
# 1   0.333333          0         0  0.000000   ...           0
# 2   0.000000          0         0  0.000000   ...           0
# 3   0.000000          0         0  0.333333   ...           0
# 4   0.000000          0         0  0.000000   ...           0
#
#    Science-Fiction  Soap  Special Interest  Sport  Suspense  Talk Show  \
# 0         0.333333     0                 0      0         0          0
# ...
